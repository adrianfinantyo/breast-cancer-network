# %%
import pandas as pd

df = pd.read_excel('./../data/adjmatrix.xlsx')

# %%
df = df.dropna(axis=0, thresh=3)
df = df.dropna(axis=1, thresh=3)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df[df < 0.5] = 0

# %%
from ipycytoscape import CytoscapeWidget
import networkx as nx

cyto = CytoscapeWidget()
graph = nx.from_numpy_matrix(df.values)
graph = nx.relabel_nodes(graph, dict(enumerate(df.columns)))
nodes_of_largest_component  = max(nx.connected_components(graph), key = len)
print(len(nodes_of_largest_component))
g = graph.subgraph(nodes_of_largest_component)

for node in g.nodes(data=True):
    node[1]["classes"] = 'class1'
    
for s, t, data in g.edges(data=True):
    g[s][t]['classes'] = 'class1'
    
cyto.graph.add_graph_from_networkx(graph)
cyto.set_style(
    [
        {
             'selector': 'node.class1',
             'style': {
                 'background-color': 'green'
             }
        },
        {
             'selector': 'edge.class1',
             'style': {
                 'line-color': '#A0FFA0'
             }
        }
    ]
)
display(cyto)
# Out:
# 323

# %%
cyto_largest = CytoscapeWidget()
cyto_largest.graph.add_graph_from_networkx(g)
cyto_largest.set_style(
    [
        {
             'selector': 'node',
             'style': {
                 'background-color': 'green'
             }
        },
        {
             'selector': 'edge',
             'style': {
                 'line-color': '#A0FFA0'
             }
        }
    ]
)
display(cyto_largest)

# %%
from cdlib import algorithms, viz

# Value of k = ?
#coms = algorithms.async_fluid(g, k=?)
#pos = nx.spring_layout(g)
#viz.plot_network_clusters(g, coms, pos)

# %%
# from cdlib import evaluation

# m1 = evaluation.erdos_renyi_modularity(g, coms)
# m2 = evaluation.link_modularity(g, coms)
# m3 = evaluation.modularity_density(g, coms)
# m4 = evaluation.newman_girvan_modularity(g, coms)
# m5 = evaluation.z_modularity(g, coms)

# print(m1.score)
# print(m2.score)
# print(m3.score)
# print(m4.score)
# print(m5.score)

# %%
# ae = evaluation.avg_embeddedness(g, coms)
# aid = evaluation.average_internal_degree(g, coms)
# at = evaluation.avg_transitivity(g, coms)
# c = evaluation.conductance(g, coms)
# cr = evaluation.cut_ratio(g, coms)
# ei = evaluation.edges_inside(g, coms)
# ex = evaluation.expansion(g, coms)
# fomd = evaluation.fraction_over_median_degree(g, coms)
# ied = evaluation.internal_edge_density(g, coms)
# nc = evaluation.normalized_cut(g, coms)
# modf = evaluation.max_odf(g, coms)
# aodf = evaluation.avg_odf(g, coms)
# fodf = evaluation.flake_odf(g, coms)
# sd = evaluation.scaled_density(g, coms)
# sz = evaluation.size(g, coms)
# tpr = evaluation.triangle_participation_ratio(g, coms)

# print(ae.score)
# print(aid.score)
# print(at.score)
# print(c.score)
# print(cr.score)
# print(ei.score)
# print(ex.score)
# print(fomd.score)
# print(ied.score)
# print(nc.score)
# print(modf.score)
# print(aodf.score)
# print(fodf.score)
# print(sd.score)
# print(sz.score)
# print(tpr.score)

# %%
# bc = nx.betweenness_centrality(coms)
# dc = nx.degree_centrality(coms)
# cc = nx.closeness_centrality(coms)
# ev = nx.eigenvector_centrality(coms)

# print(bc)
# print(dc)
# print(cc)
# print(ev)

# %%
coms = algorithms.belief(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
from cdlib import evaluation

m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8288587589446571
# 0.10707306640050138
# 57.36444336098523
# 0.8322230194691961
# 2.342025181674074

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.9795591093912412
# 8.444996875223
# 0.7496173565558346
# 0.02959509639317614
# 0.0009058798362956699
# 194.28571428571428
# 0.25007639508225216
# 0.4498328567076901
# 0.1895791206270108
# 0.03442184018702833
# 5.285714285714286
# 0.25007639508225216
# 0.0
# 7.036890085629153
# 46.142857142857146
# 0.908175624840135

# %%
bc = nx.betweenness_centrality(g)
dc = nx.degree_centrality(g)
cc = nx.closeness_centrality(g)
ev = nx.eigenvector_centrality(g, max_iter=1000)

print("Betweenness Centrality")
print(sorted(((v, f"{c:0.2f}") for v, c in bc.items()), key=lambda x: x[1], reverse=True)
)
print("\nDegree Centrality")
print(sorted(((v, f"{c:0.2f}") for v, c in dc.items()), key=lambda x: x[1], reverse=True)
)
print("\nCloseness Centrality")
print(sorted(((v, f"{c:0.2f}") for v, c in cc.items()), key=lambda x: x[1], reverse=True)
)
print("\nEigenvector Centrality")
print(sorted(((v, f"{c:0.2f}") for v, c in ev.items()), key=lambda x: x[1], reverse=True)
)
# Out:
# Betweenness Centrality
# [('DOID.863', '0.55'), ('DOID.77', '0.33'), ('DOID.12217', '0.24'), ('DOID.1307', '0.24'), ('DOID.417', '0.22'), ('DOID.1287', '0.21'), ('DOID.1289', '0.17'), ('DOID.17', '0.15'), ('DOID.150', '0.14'), ('DOID.437', '0.13'), ('DOID.3635', '0.13'), ('DOID.1579', '0.12'), ('DOID.8505', '0.12'), ('DOID.14330', '0.11'), ('DOID.2723', '0.11'), ('DOID.12858', '0.10'), ('DOID.12899', '0.07'), ('DOID.1561', '0.07'), ('DOID.331', '0.07'), ('DOID.0050736', '0.06'), ('DOID.12236', '0.05'), ('DOID.11823', '0.05'), ('DOID.409', '0.05'), ('DOID.5082', '0.04'), ('DOID.10854', '0.04'), ('DOID.0080001', '0.04'), ('DOID.790', '0.04'), ('DOID.0060260', '0.04'), ('DOID.7188', '0.04'), ('DOID.9335', '0.04'), ('DOID.0060056', '0.03'), ('DOID.10302', '0.03'), ('DOID.0060037', '0.03'), ('DOID.3021', '0.03'), ('DOID.2237', '0.02'), ('DOID.3688', '0.02'), ('DOID.633', '0.02'), ('DOID.630', '0.02'), ('DOID.8466', '0.02'), ('DOID.870', '0.02'), ('DOID.114', '0.02'), ('DOID.50', '0.02'), ('DOID.3393', '0.01'), ('DOID.381', '0.01'), ('DOID.11561', '0.01'), ('DOID.11552', '0.01'), ('DOID.8483', '0.01'), ('DOID.0060038', '0.01'), ('DOID.0050161', '0.01'), ('DOID.1826', '0.01'), ('DOID.12510', '0.01'), ('DOID.0050700', '0.01'), ('DOID.3083', '0.01'), ('DOID.11984', '0.01'), ('DOID.612', '0.01'), ('DOID.7187', '0.01'), ('DOID.848', '0.01'), ('DOID.866', '0.01'), ('DOID.6929', '0.01'), ('DOID.6713', '0.01'), ('DOID.5844', '0.01'), ('DOID.850', '0.01'), ('DOID.1432', '0.01'), ('DOID.4138', '0.01'), ('DOID.767', '0.01'), ('DOID.3324', '0.01'), ('DOID.2030', '0.01'), ('DOID.699', '0.01'), ('DOID.557', '0.01'), ('DOID.10763', '0.01'), ('DOID.13072', '0.01'), ('DOID.11199', '0.01'), ('DOID.1727', '0.01'), ('DOID.6873', '0.01'), ('DOID.3342', '0.01'), ('DOID.12556', '0.01'), ('DOID.10123', '0.01'), ('DOID.9601', '0.00'), ('DOID.11668', '0.00'), ('DOID.8577', '0.00'), ('DOID.0060041', '0.00'), ('DOID.3883', '0.00'), ('DOID.9767', '0.00'), ('DOID.7439', '0.00'), ('DOID.0060149', '0.00'), ('DOID.10808', '0.00'), ('DOID.0060025', '0.00'), ('DOID.8927', '0.00'), ('DOID.14789', '0.00'), ('DOID.7725', '0.00'), ('DOID.11389', '0.00'), ('DOID.12716', '0.00'), ('DOID.2377', '0.00'), ('DOID.0060046', '0.00'), ('DOID.3602', '0.00'), ('DOID.8778', '0.00'), ('DOID.10378', '0.00'), ('DOID.8514', '0.00'), ('DOID.0050431', '0.00'), ('DOID.6000', '0.00'), ('DOID.1470', '0.00'), ('DOID.9207', '0.00'), ('DOID.3764', '0.00'), ('DOID.11577', '0.00'), ('DOID.11335', '0.00'), ('DOID.1059', '0.00'), ('DOID.13094', '0.00'), ('DOID.9408', '0.00'), ('DOID.11486', '0.00'), ('DOID.824', '0.00'), ('DOID.2768', '0.00'), ('DOID.0050185', '0.00'), ('DOID.1184', '0.00'), ('DOID.8893', '0.00'), ('DOID.0050562', '0.00'), ('DOID.3122', '0.00'), ('DOID.1596', '0.00'), ('DOID.10600', '0.00'), ('DOID.1787', '0.00'), ('DOID.2491', '0.00'), ('DOID.0050426', '0.00'), ('DOID.12098', '0.00'), ('DOID.750', '0.00'), ('DOID.10122', '0.00'), ('DOID.1509', '0.00'), ('DOID.8925', '0.00'), ('DOID.8398', '0.00'), ('DOID.6688', '0.00'), ('DOID.0050681', '0.00'), ('DOID.0050548', '0.00'), ('DOID.0050852', '0.00'), ('DOID.6132', '0.00'), ('DOID.11120', '0.00'), ('DOID.6432', '0.00'), ('DOID.0060181', '0.00'), ('DOID.12721', '0.00'), ('DOID.0050204', '0.00'), ('DOID.8255', '0.00'), ('DOID.5749', '0.00'), ('DOID.4724', '0.00'), ('DOID.13543', '0.00'), ('DOID.0060224', '0.00'), ('DOID.1578', '0.00'), ('DOID.1073', '0.00'), ('DOID.12705', '0.00'), ('DOID.9743', '0.00'), ('DOID.6088', '0.00'), ('DOID.3783', '0.00'), ('DOID.11963', '0.00'), ('DOID.8545', '0.00'), ('DOID.10031', '0.00'), ('DOID.2797', '0.00'), ('DOID.9074', '0.00'), ('DOID.10588', '0.00'), ('DOID.0060244', '0.00'), ('DOID.6457', '0.00'), ('DOID.12704', '0.00'), ('DOID.339', '0.00'), ('DOID.5419', '0.00'), ('DOID.783', '0.00'), ('DOID.9867', '0.00'), ('DOID.0050667', '0.00'), ('DOID.784', '0.00'), ('DOID.9478', '0.00'), ('DOID.13515', '0.00'), ('DOID.8741', '0.00'), ('DOID.0050784', '0.00'), ('DOID.13413', '0.00'), ('DOID.13250', '0.00'), ('DOID.2477', '0.00'), ('D ...
#
# Degree Centrality
# [('DOID.863', '0.15'), ('DOID.77', '0.12'), ('DOID.1287', '0.10'), ('DOID.331', '0.10'), ('DOID.150', '0.09'), ('DOID.0050161', '0.07'), ('DOID.1561', '0.07'), ('DOID.850', '0.07'), ('DOID.1289', '0.07'), ('DOID.0060037', '0.07'), ('DOID.0060038', '0.06'), ('DOID.0050736', '0.06'), ('DOID.0080001', '0.06'), ('DOID.3082', '0.06'), ('DOID.552', '0.06'), ('DOID.2723', '0.06'), ('DOID.1579', '0.06'), ('DOID.417', '0.06'), ('DOID.870', '0.06'), ('DOID.3393', '0.05'), ('DOID.0050185', '0.05'), ('DOID.8893', '0.05'), ('DOID.1826', '0.05'), ('DOID.0050426', '0.05'), ('DOID.4724', '0.05'), ('DOID.13413', '0.05'), ('DOID.1584', '0.05'), ('DOID.790', '0.05'), ('DOID.3488', '0.05'), ('DOID.0060260', '0.05'), ('DOID.0060056', '0.05'), ('DOID.9335', '0.05'), ('DOID.1558', '0.05'), ('DOID.17', '0.05'), ('DOID.8466', '0.05'), ('DOID.12858', '0.05'), ('DOID.6364', '0.05'), ('DOID.0050850', '0.05'), ('DOID.10123', '0.05'), ('DOID.3883', '0.04'), ('DOID.8927', '0.04'), ('DOID.11389', '0.04'), ('DOID.11561', '0.04'), ('DOID.3764', '0.04'), ('DOID.1059', '0.04'), ('DOID.12510', '0.04'), ('DOID.3083', '0.04'), ('DOID.2797', '0.04'), ('DOID.6457', '0.04'), ('DOID.13515', '0.04'), ('DOID.1094', '0.04'), ('DOID.10017', '0.04'), ('DOID.866', '0.04'), ('DOID.6929', '0.04'), ('DOID.6713', '0.04'), ('DOID.0050424', '0.04'), ('DOID.5353', '0.04'), ('DOID.5683', '0.04'), ('DOID.5844', '0.04'), ('DOID.8437', '0.04'), ('DOID.1432', '0.04'), ('DOID.9477', '0.04'), ('DOID.2769', '0.04'), ('DOID.3324', '0.04'), ('DOID.11516', '0.04'), ('DOID.2303', '0.04'), ('DOID.10763', '0.04'), ('DOID.3240', '0.04'), ('DOID.3012', '0.04'), ('DOID.5870', '0.04'), ('DOID.114', '0.04'), ('DOID.3342', '0.04'), ('DOID.8712', '0.04'), ('DOID.12716', '0.03'), ('DOID.381', '0.03'), ('DOID.8778', '0.03'), ('DOID.6000', '0.03'), ('DOID.2768', '0.03'), ('DOID.3688', '0.03'), ('DOID.1596', '0.03'), ('DOID.10600', '0.03'), ('DOID.10122', '0.03'), ('DOID.0050700', '0.03'), ('DOID.6132', '0.03'), ('DOID.6432', '0.03'), ('DOID.9743', '0.03'), ('DOID.8741', '0.03'), ('DOID.11295', '0.03'), ('DOID.3770', '0.03'), ('DOID.848', '0.03'), ('DOID.12783', '0.03'), ('DOID.3852', '0.03'), ('DOID.8689', '0.03'), ('DOID.1595', '0.03'), ('DOID.0060180', '0.03'), ('DOID.633', '0.03'), ('DOID.0050156', '0.03'), ('DOID.2841', '0.03'), ('DOID.9779', '0.03'), ('DOID.409', '0.03'), ('DOID.535', '0.03'), ('DOID.0060304', '0.03'), ('DOID.7736', '0.03'), ('DOID.1195', '0.03'), ('DOID.0060321', '0.03'), ('DOID.767', '0.03'), ('DOID.3310', '0.03'), ('DOID.2030', '0.03'), ('DOID.9212', '0.03'), ('DOID.678', '0.03'), ('DOID.11371', '0.03'), ('DOID.699', '0.03'), ('DOID.0050158', '0.03'), ('DOID.3817', '0.03'), ('DOID.557', '0.03'), ('DOID.13072', '0.03'), ('DOID.9255', '0.03'), ('DOID.4079', '0.03'), ('DOID.0050433', '0.03'), ('DOID.8947', '0.03'), ('DOID.11156', '0.03'), ('DOID.11394', '0.03'), ('DOID.6873', '0.03'), ('DOID.8805', '0.03'), ('DOID.3021', '0.03'), ('DOID.11949', '0.03'), ('DOID.326', '0.03'), ('DOID.9601', '0.02'), ('DOID.8577', '0.02'), ('DOID.0060041', '0.02'), ('DOID.9767', '0.02'), ('DOID.0060149', '0.02'), ('DOID.14789', '0.02'), ('DOID.2377', '0.02'), ('DOID.0060046', '0.02'), ('DOID.3602', '0.02'), ('DOID.10378', '0.02'), ('DOID.8514', '0.02'), ('DOID.0050431', '0.02'), ('DOID.12899', '0.02'), ('DOID.1470', '0.02'), ('DOID.9207', '0.02'), ('DOID.11552', '0.02'), ('DOID.11335', '0.02'), ('DOID.8483', '0.02'), ('DOID.13094', '0.02'), ('DOID.2237', '0.02'), ('DOID.9408', '0.02'), ('DOID.824', '0.02'), ('DOID.1184', '0.02'), ('DOID.3122', '0.02'), ('DOID.5082', '0.02'), ('DOID.10854', '0.02'), ('DOID.2491', '0.02'), ('DOID.12098', '0.02'), ('DOID.750', '0.02'), ('DOID.8925', '0.02'), ('DOID.8398', '0.02'), ('DOID.6688', '0.02'), ('DOID.0050548', '0.02'), ('DOID.0050852', '0.02'), ('DOID.0060181', '0.02'), ('DOID.12721', '0.02'), ('DOID.0050204', '0.02'), ('DOID.5749', '0.02'), ('DOID.1073', '0.02'), ('DOID.6088', '0.02'), ('DOID.10031', '0.02'), ('DOID.9074', '0.02'), ('DOID.0060244', '0.02'), ('DO ...
#
# Closeness Centrality
# [('DOID.863', '0.32'), ('DOID.77', '0.30'), ('DOID.17', '0.28'), ('DOID.1289', '0.28'), ('DOID.1287', '0.28'), ('DOID.1579', '0.28'), ('DOID.14330', '0.27'), ('DOID.331', '0.27'), ('DOID.11389', '0.26'), ('DOID.2377', '0.26'), ('DOID.3688', '0.26'), ('DOID.1826', '0.26'), ('DOID.4724', '0.26'), ('DOID.13413', '0.26'), ('DOID.10310', '0.26'), ('DOID.3635', '0.26'), ('DOID.10652', '0.26'), ('DOID.870', '0.26'), ('DOID.9470', '0.26'), ('DOID.6364', '0.26'), ('DOID.639', '0.26'), ('DOID.0050850', '0.26'), ('DOID.3602', '0.25'), ('DOID.5082', '0.25'), ('DOID.10854', '0.25'), ('DOID.2491', '0.25'), ('DOID.0050548', '0.25'), ('DOID.9743', '0.25'), ('DOID.2477', '0.25'), ('DOID.790', '0.25'), ('DOID.12783', '0.25'), ('DOID.0060260', '0.25'), ('DOID.409', '0.25'), ('DOID.9335', '0.25'), ('DOID.1195', '0.25'), ('DOID.10302', '0.25'), ('DOID.678', '0.25'), ('DOID.3817', '0.25'), ('DOID.9255', '0.25'), ('DOID.0050433', '0.25'), ('DOID.11949', '0.25'), ('DOID.10595', '0.25'), ('DOID.7439', '0.24'), ('DOID.11577', '0.24'), ('DOID.2237', '0.24'), ('DOID.11486', '0.24'), ('DOID.12098', '0.24'), ('DOID.339', '0.24'), ('DOID.3388', '0.24'), ('DOID.4138', '0.24'), ('DOID.9297', '0.24'), ('DOID.1884', '0.24'), ('DOID.1389', '0.24'), ('DOID.8681', '0.24'), ('DOID.10865', '0.24'), ('DOID.8577', '0.23'), ('DOID.10808', '0.23'), ('DOID.8778', '0.23'), ('DOID.437', '0.23'), ('DOID.824', '0.23'), ('DOID.3122', '0.23'), ('DOID.750', '0.23'), ('DOID.0060181', '0.23'), ('DOID.11963', '0.23'), ('DOID.12217', '0.23'), ('DOID.13250', '0.23'), ('DOID.3852', '0.23'), ('DOID.0060180', '0.23'), ('DOID.12234', '0.23'), ('DOID.633', '0.23'), ('DOID.5353', '0.23'), ('DOID.8437', '0.23'), ('DOID.9779', '0.23'), ('DOID.13580', '0.23'), ('DOID.0060321', '0.23'), ('DOID.767', '0.23'), ('DOID.0060328', '0.23'), ('DOID.11371', '0.23'), ('DOID.11516', '0.23'), ('DOID.699', '0.23'), ('DOID.12858', '0.23'), ('DOID.4029', '0.23'), ('DOID.10487', '0.23'), ('DOID.12642', '0.23'), ('DOID.114', '0.23'), ('DOID.8534', '0.23'), ('DOID.8757', '0.23'), ('DOID.9601', '0.22'), ('DOID.12716', '0.22'), ('DOID.3393', '0.22'), ('DOID.381', '0.22'), ('DOID.8514', '0.22'), ('DOID.6000', '0.22'), ('DOID.8483', '0.22'), ('DOID.0050161', '0.22'), ('DOID.1787', '0.22'), ('DOID.0050852', '0.22'), ('DOID.6432', '0.22'), ('DOID.5749', '0.22'), ('DOID.0060224', '0.22'), ('DOID.12705', '0.22'), ('DOID.3083', '0.22'), ('DOID.2797', '0.22'), ('DOID.0050784', '0.22'), ('DOID.3770', '0.22'), ('DOID.848', '0.22'), ('DOID.0080001', '0.22'), ('DOID.1584', '0.22'), ('DOID.3082', '0.22'), ('DOID.866', '0.22'), ('DOID.9775', '0.22'), ('DOID.6713', '0.22'), ('DOID.1532', '0.22'), ('DOID.5844', '0.22'), ('DOID.850', '0.22'), ('DOID.5587', '0.22'), ('DOID.14224', '0.22'), ('DOID.9477', '0.22'), ('DOID.552', '0.22'), ('DOID.10763', '0.22'), ('DOID.3240', '0.22'), ('DOID.11695', '0.22'), ('DOID.13738', '0.22'), ('DOID.9598', '0.22'), ('DOID.4079', '0.22'), ('DOID.9651', '0.22'), ('DOID.5870', '0.22'), ('DOID.10159', '0.22'), ('DOID.118', '0.22'), ('DOID.1727', '0.22'), ('DOID.11394', '0.22'), ('DOID.8805', '0.22'), ('DOID.3342', '0.22'), ('DOID.0050650', '0.22'), ('DOID.326', '0.22'), ('DOID.7725', '0.21'), ('DOID.12899', '0.21'), ('DOID.0050562', '0.21'), ('DOID.10588', '0.21'), ('DOID.12236', '0.21'), ('DOID.0050837', '0.21'), ('DOID.10908', '0.21'), ('DOID.0050754', '0.21'), ('DOID.12506', '0.21'), ('DOID.10378', '0.20'), ('DOID.11561', '0.20'), ('DOID.11552', '0.20'), ('DOID.12510', '0.20'), ('DOID.0050700', '0.20'), ('DOID.0050204', '0.20'), ('DOID.11823', '0.20'), ('DOID.6929', '0.20'), ('DOID.11518', '0.20'), ('DOID.83', '0.20'), ('DOID.1432', '0.20'), ('DOID.8466', '0.20'), ('DOID.417', '0.20'), ('DOID.0060261', '0.20'), ('DOID.9935', '0.20'), ('DOID.1307', '0.20'), ('DOID.3883', '0.19'), ('DOID.0050431', '0.19'), ('DOID.3764', '0.19'), ('DOID.0050736', '0.19'), ('DOID.1073', '0.19'), ('DOID.6457', '0.19'), ('DOID.13515', '0.19'), ('DOID.10017', '0.19'), ('DOID.970', '0.19'), ('DOID.14286', '0.19'), ('DOID ...
#
# Eigenvector Centrality
# [('DOID.863', '0.39'), ('DOID.331', '0.32'), ('DOID.1826', '0.24'), ('DOID.1289', '0.24'), ('DOID.4724', '0.23'), ('DOID.13413', '0.23'), ('DOID.6364', '0.23'), ('DOID.0050850', '0.23'), ('DOID.11389', '0.20'), ('DOID.0050433', '0.16'), ('DOID.11949', '0.16'), ('DOID.12783', '0.15'), ('DOID.678', '0.15'), ('DOID.9255', '0.15'), ('DOID.3688', '0.12'), ('DOID.870', '0.12'), ('DOID.1579', '0.11'), ('DOID.10310', '0.10'), ('DOID.9470', '0.10'), ('DOID.2377', '0.09'), ('DOID.14330', '0.09'), ('DOID.10652', '0.09'), ('DOID.639', '0.09'), ('DOID.77', '0.08'), ('DOID.0050161', '0.08'), ('DOID.9743', '0.08'), ('DOID.850', '0.08'), ('DOID.1195', '0.08'), ('DOID.1287', '0.08'), ('DOID.3602', '0.07'), ('DOID.1584', '0.07'), ('DOID.3082', '0.07'), ('DOID.552', '0.07'), ('DOID.12858', '0.07'), ('DOID.2491', '0.06'), ('DOID.0050548', '0.06'), ('DOID.2477', '0.06'), ('DOID.790', '0.06'), ('DOID.0060260', '0.06'), ('DOID.9335', '0.06'), ('DOID.17', '0.06'), ('DOID.3817', '0.06'), ('DOID.10595', '0.06'), ('DOID.12098', '0.05'), ('DOID.3083', '0.05'), ('DOID.2797', '0.05'), ('DOID.339', '0.05'), ('DOID.0050784', '0.05'), ('DOID.3635', '0.05'), ('DOID.3240', '0.05'), ('DOID.8681', '0.05'), ('DOID.5870', '0.05'), ('DOID.10865', '0.05'), ('DOID.7725', '0.04'), ('DOID.12716', '0.04'), ('DOID.0050562', '0.04'), ('DOID.6132', '0.04'), ('DOID.12705', '0.04'), ('DOID.3770', '0.04'), ('DOID.0050837', '0.04'), ('DOID.1532', '0.04'), ('DOID.2841', '0.04'), ('DOID.11394', '0.04'), ('DOID.7439', '0.03'), ('DOID.11561', '0.03'), ('DOID.11577', '0.03'), ('DOID.11486', '0.03'), ('DOID.12510', '0.03'), ('DOID.10588', '0.03'), ('DOID.12217', '0.03'), ('DOID.6929', '0.03'), ('DOID.0050156', '0.03'), ('DOID.1432', '0.03'), ('DOID.10908', '0.03'), ('DOID.0050158', '0.03'), ('DOID.8466', '0.03'), ('DOID.1389', '0.03'), ('DOID.0050754', '0.03'), ('DOID.3883', '0.02'), ('DOID.3393', '0.02'), ('DOID.8778', '0.02'), ('DOID.3764', '0.02'), ('DOID.0050736', '0.02'), ('DOID.10031', '0.02'), ('DOID.6457', '0.02'), ('DOID.13515', '0.02'), ('DOID.10017', '0.02'), ('DOID.866', '0.02'), ('DOID.3852', '0.02'), ('DOID.0060180', '0.02'), ('DOID.6713', '0.02'), ('DOID.0050424', '0.02'), ('DOID.11289', '0.02'), ('DOID.5353', '0.02'), ('DOID.5683', '0.02'), ('DOID.8437', '0.02'), ('DOID.9779', '0.02'), ('DOID.9477', '0.02'), ('DOID.0060321', '0.02'), ('DOID.11516', '0.02'), ('DOID.10763', '0.02'), ('DOID.3012', '0.02'), ('DOID.8712', '0.02'), ('DOID.12323', '0.02'), ('DOID.9601', '0.01'), ('DOID.8577', '0.01'), ('DOID.10808', '0.01'), ('DOID.381', '0.01'), ('DOID.10378', '0.01'), ('DOID.8514', '0.01'), ('DOID.6000', '0.01'), ('DOID.11552', '0.01'), ('DOID.8483', '0.01'), ('DOID.2237', '0.01'), ('DOID.824', '0.01'), ('DOID.3122', '0.01'), ('DOID.5082', '0.01'), ('DOID.10854', '0.01'), ('DOID.1787', '0.01'), ('DOID.750', '0.01'), ('DOID.0050852', '0.01'), ('DOID.6432', '0.01'), ('DOID.0060181', '0.01'), ('DOID.5749', '0.01'), ('DOID.0060224', '0.01'), ('DOID.11963', '0.01'), ('DOID.13250', '0.01'), ('DOID.11295', '0.01'), ('DOID.848', '0.01'), ('DOID.0080001', '0.01'), ('DOID.9775', '0.01'), ('DOID.11282', '0.01'), ('DOID.11518', '0.01'), ('DOID.3388', '0.01'), ('DOID.83', '0.01'), ('DOID.12234', '0.01'), ('DOID.633', '0.01'), ('DOID.5844', '0.01'), ('DOID.5587', '0.01'), ('DOID.14224', '0.01'), ('DOID.409', '0.01'), ('DOID.13580', '0.01'), ('DOID.4447', '0.01'), ('DOID.4138', '0.01'), ('DOID.7736', '0.01'), ('DOID.767', '0.01'), ('DOID.0060328', '0.01'), ('DOID.9297', '0.01'), ('DOID.10302', '0.01'), ('DOID.1884', '0.01'), ('DOID.11371', '0.01'), ('DOID.699', '0.01'), ('DOID.11695', '0.01'), ('DOID.13738', '0.01'), ('DOID.4029', '0.01'), ('DOID.9598', '0.01'), ('DOID.4079', '0.01'), ('DOID.10487', '0.01'), ('DOID.12506', '0.01'), ('DOID.12642', '0.01'), ('DOID.0060261', '0.01'), ('DOID.9935', '0.01'), ('DOID.9651', '0.01'), ('DOID.8947', '0.01'), ('DOID.10159', '0.01'), ('DOID.114', '0.01'), ('DOID.118', '0.01'), ('DOID.1727', '0.01'), ('DOID.8805', '0.01'), ('DOID.8534', '0.01'), ('DO ...

# %%
coms = algorithms.cpm(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.2305496074232691
# 0.0
# -1510.0
# 0.32285763925124483
# 3.4316485879321283

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.30818844445613386
# 2.0
# 0.0
# 0.6918115555438661
# 0.02072957329384843
# 1.0
# 6.674922600619195
# 0.0
# 0.0
# 0.6941859048707258
# 6.674922600619195
# 6.674922600619195
# 0.8328173374613003
# 0.0
# 1.0
# 0.0

# %%
bc = nx.betweenness_centrality(coms)
dc = nx.degree_centrality(coms)
cc = nx.closeness_centrality(coms)
ev = nx.eigenvector_centrality(coms)

print(bc)
print(dc)
print(cc)
print(ev)

# %%
# Frozen graph can't be modified
# coms = algorithms.chinesewhispers(g)
# pos = nx.spring_layout(g)
# viz.plot_network_clusters(g, coms, pos)

# %%
# m1 = evaluation.erdos_renyi_modularity(g, coms)
# m2 = evaluation.link_modularity(g, coms)
# m3 = evaluation.modularity_density(g, coms)
# m4 = evaluation.newman_girvan_modularity(g, coms)
# m5 = evaluation.z_modularity(g, coms)

# print(m1.score)
# print(m2.score)
# print(m3.score)
# print(m4.score)
# print(m5.score)

# %%
# ae = evaluation.avg_embeddedness(g, coms)
# aid = evaluation.average_internal_degree(g, coms)
# at = evaluation.avg_transitivity(g, coms)
# c = evaluation.conductance(g, coms)
# cr = evaluation.cut_ratio(g, coms)
# ei = evaluation.edges_inside(g, coms)
# ex = evaluation.expansion(g, coms)
# fomd = evaluation.fraction_over_median_degree(g, coms)
# ied = evaluation.internal_edge_density(g, coms)
# nc = evaluation.normalized_cut(g, coms)
# modf = evaluation.max_odf(g, coms)
# aodf = evaluation.avg_odf(g, coms)
# fodf = evaluation.flake_odf(g, coms)
# sd = evaluation.scaled_density(g, coms)
# sz = evaluation.size(g, coms)
# tpr = evaluation.triangle_participation_ratio(g, coms)

# print(ae.score)
# print(aid.score)
# print(at.score)
# print(c.score)
# print(cr.score)
# print(ei.score)
# print(ex.score)
# print(fomd.score)
# print(ied.score)
# print(nc.score)
# print(modf.score)
# print(aodf.score)
# print(fodf.score)
# print(sd.score)
# print(sz.score)
# print(tpr.score)

# %%
coms = algorithms.der(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.45907012200457387
# 0.10696962056197075
# 16.363636363636363
# 0.46728809299546503
# 0.923480527419625

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.9770721806935869
# 8.448529411764707
# 0.7290465646569326
# 0.030487451037284202
# 0.001651462724127084
# 679.5
# 0.2667112299465241
# 0.47660427807486627
# 0.054218497434816215
# 0.05919678753261853
# 10.5
# 0.2667112299465241
# 0.0
# 2.012508581086901
# 161.5
# 0.8960561497326203

# %%
coms = algorithms.eigenvector(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8397818371072672
# 0.0966450164688614
# 122.02863472784526
# 0.8482318286536179
# 3.2610074118889814

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.8345156549151063
# 6.166895567320669
# 0.5918220663851131
# 0.17931568025446845
# 0.0046732483854785714
# 48.42307692307692
# 1.4734865393266203
# 0.23079232845427175
# 0.9671154601808308
# 0.18342106052577628
# 5.038461538461538
# 1.4734865393266203
# 0.08535762483130904
# 35.89786243810404
# 12.423076923076923
# 0.6930801897907161

# %%
#coms = algorithms.em(g, k=?)
#pos = nx.spring_layout(g)
#viz.plot_network_clusters(g, coms, pos)

# %%
# m1 = evaluation.erdos_renyi_modularity(g, coms)
# m2 = evaluation.link_modularity(g, coms)
# m3 = evaluation.modularity_density(g, coms)
# m4 = evaluation.newman_girvan_modularity(g, coms)
# m5 = evaluation.z_modularity(g, coms)

# print(m1.score)
# print(m2.score)
# print(m3.score)
# print(m4.score)
# print(m5.score)

# %%
# ae = evaluation.avg_embeddedness(g, coms)
# aid = evaluation.average_internal_degree(g, coms)
# at = evaluation.avg_transitivity(g, coms)
# c = evaluation.conductance(g, coms)
# cr = evaluation.cut_ratio(g, coms)
# ei = evaluation.edges_inside(g, coms)
# ex = evaluation.expansion(g, coms)
# fomd = evaluation.fraction_over_median_degree(g, coms)
# ied = evaluation.internal_edge_density(g, coms)
# nc = evaluation.normalized_cut(g, coms)
# modf = evaluation.max_odf(g, coms)
# aodf = evaluation.avg_odf(g, coms)
# fodf = evaluation.flake_odf(g, coms)
# sd = evaluation.scaled_density(g, coms)
# sz = evaluation.size(g, coms)
# tpr = evaluation.triangle_participation_ratio(g, coms)

# print(ae.score)
# print(aid.score)
# print(at.score)
# print(c.score)
# print(cr.score)
# print(ei.score)
# print(ex.score)
# print(fomd.score)
# print(ied.score)
# print(nc.score)
# print(modf.score)
# print(aodf.score)
# print(fodf.score)
# print(sd.score)
# print(sz.score)
# print(tpr.score)

# %%
coms = algorithms.ga(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.6425842971805711
# 0.0627781167915366
# 40.19141414141413
# 0.630303836201428
# 3.467062300358518

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.5832667653112732
# 3.636762101534829
# 0.2802121040017335
# 0.44410270636338944
# 0.00994989054236982
# 10.579545454545455
# 3.1800414862914863
# 0.09782975862521318
# 1.0741732457975774
# 0.44793728273049904
# 5.693181818181818
# 3.1800414862914863
# 0.3218893480257117
# 39.87168543983684
# 3.6704545454545454
# 0.31841056670602125

# %%
# Value of level = ?
# coms = algorithms.girvan_newman(g, level=?)
# pos = nx.spring_layout(g)
# viz.plot_network_clusters(g, coms, pos)

# %%
# m1 = evaluation.erdos_renyi_modularity(g, coms)
# m2 = evaluation.link_modularity(g, coms)
# m3 = evaluation.modularity_density(g, coms)
# m4 = evaluation.newman_girvan_modularity(g, coms)
# m5 = evaluation.z_modularity(g, coms)

# print(m1.score)
# print(m2.score)
# print(m3.score)
# print(m4.score)
# print(m5.score)

# %%
# ae = evaluation.avg_embeddedness(g, coms)
# aid = evaluation.average_internal_degree(g, coms)
# at = evaluation.avg_transitivity(g, coms)
# c = evaluation.conductance(g, coms)
# cr = evaluation.cut_ratio(g, coms)
# ei = evaluation.edges_inside(g, coms)
# ex = evaluation.expansion(g, coms)
# fomd = evaluation.fraction_over_median_degree(g, coms)
# ied = evaluation.internal_edge_density(g, coms)
# nc = evaluation.normalized_cut(g, coms)
# modf = evaluation.max_odf(g, coms)
# aodf = evaluation.avg_odf(g, coms)
# fodf = evaluation.flake_odf(g, coms)
# sd = evaluation.scaled_density(g, coms)
# sz = evaluation.size(g, coms)
# tpr = evaluation.triangle_participation_ratio(g, coms)

# print(ae.score)
# print(aid.score)
# print(at.score)
# print(c.score)
# print(cr.score)
# print(ei.score)
# print(ex.score)
# print(fomd.score)
# print(ied.score)
# print(nc.score)
# print(modf.score)
# print(aodf.score)
# print(fodf.score)
# print(sd.score)
# print(sz.score)
# print(tpr.score)

# %%
coms = algorithms.greedy_modularity(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8740507379996182
# 0.10717625189015946
# 106.1353735577178
# 0.867665647205193
# 2.844998987043929

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.9726497740121108
# 7.854547437176012
# 0.7461123864994208
# 0.03614860875837069
# 0.0009073416637938602
# 97.21428571428571
# 0.27344932591045573
# 0.32476680784332934
# 0.5904438111329043
# 0.03839559934252971
# 3.0
# 0.27344932591045573
# 0.0014005602240896359
# 21.916380806812587
# 23.071428571428573
# 0.8916487164511074

# %%
coms = algorithms.kcut(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# -0.004883153188754609
# 0.10438813797564607
# -49.79746835443038
# 0.012376700439830727
# 0.05203433161403451

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.32922042268468366
# 2.7998417721518987
# 0.08891252633000671
# 0.6706405350090917
# 0.03145392719553424
# 166.75
# 9.024525316455696
# 0.055379746835443035
# 0.0033328310227044404
# 0.7107344933955408
# 9.375
# 9.024525316455696
# 0.875
# 0.12370964430670879
# 40.375
# 0.11115506329113924

# %%
coms = algorithms.label_propagation(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.2305496074232691
# 0.0
# -1510.0
# 0.2261862002311998
# 3.4316485879321283

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.30818844445613386
# 2.0
# 0.0
# 0.6918115555438661
# 0.02072957329384843
# 1.0
# 6.674922600619195
# 0.0
# 0.0
# 0.6941859048707258
# 6.674922600619195
# 6.674922600619195
# 0.8328173374613003
# 0.0
# 1.0
# 0.0

# %%
coms = algorithms.leiden(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8853734526900885
# 0.1061438357413306
# 120.10330344258915
# 0.8774598138069016
# 3.1157895193227323

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.9675196372632172
# 7.833886054421769
# 0.7556957040269832
# 0.04376810759718026
# 0.0010787663667592158
# 84.4375
# 0.3274295892599464
# 0.33155148423005565
# 0.5823938368363539
# 0.04617294239733948
# 3.625
# 0.3274295892599464
# 0.0
# 21.61757794218481
# 20.1875
# 0.9011859131278774

# %%
coms = algorithms.louvain(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8848157925550962
# 0.10614383563454184
# 120.08316738816738
# 0.8771215217436715
# 3.1091161345458485

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.9679338003137647
# 7.833214285714286
# 0.7559589872924937
# 0.04384831158607078
# 0.0010806012369506388
# 84.4375
# 0.32801632395382396
# 0.3318831168831169
# 0.5832770717092505
# 0.046253473788946356
# 3.6875
# 0.32801632395382396
# 0.0
# 21.65036228415143
# 20.1875
# 0.9022700968013468

# %%
# Frozen graph can't be modified
# coms = algorithms.markov_clustering(g)
# pos = nx.spring_layout(g)
# viz.plot_network_clusters(g, coms, pos)

# %%
# m1 = evaluation.erdos_renyi_modularity(g, coms)
# m2 = evaluation.link_modularity(g, coms)
# m3 = evaluation.modularity_density(g, coms)
# m4 = evaluation.newman_girvan_modularity(g, coms)
# m5 = evaluation.z_modularity(g, coms)

# print(m1.score)
# print(m2.score)
# print(m3.score)
# print(m4.score)
# print(m5.score)

# %%
# ae = evaluation.avg_embeddedness(g, coms)
# aid = evaluation.average_internal_degree(g, coms)
# at = evaluation.avg_transitivity(g, coms)
# c = evaluation.conductance(g, coms)
# cr = evaluation.cut_ratio(g, coms)
# ei = evaluation.edges_inside(g, coms)
# ex = evaluation.expansion(g, coms)
# fomd = evaluation.fraction_over_median_degree(g, coms)
# ied = evaluation.internal_edge_density(g, coms)
# nc = evaluation.normalized_cut(g, coms)
# modf = evaluation.max_odf(g, coms)
# aodf = evaluation.avg_odf(g, coms)
# fodf = evaluation.flake_odf(g, coms)
# sd = evaluation.scaled_density(g, coms)
# sz = evaluation.size(g, coms)
# tpr = evaluation.triangle_participation_ratio(g, coms)

# print(ae.score)
# print(aid.score)
# print(at.score)
# print(c.score)
# print(cr.score)
# print(ei.score)
# print(ex.score)
# print(fomd.score)
# print(ied.score)
# print(nc.score)
# print(modf.score)
# print(aodf.score)
# print(fodf.score)
# print(sd.score)
# print(sz.score)
# print(tpr.score)

# %%
coms = algorithms.rber_pots(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8870428781472455
# 0.10511135317348956
# 134.61524044431022
# 0.8743359617200114
# 3.17206252176957

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.8997915474293362
# 6.359922495210665
# 0.5591807810109145
# 0.1100119454961042
# 0.001623788315765117
# 58.30434782608695
# 0.5070859541536994
# 0.2613250079883042
# 0.6566866641891539
# 0.11200783539700651
# 3.0869565217391304
# 0.5070859541536994
# 0.0
# 24.375215273253797
# 14.043478260869565
# 0.6651441955789782

# %%
coms = algorithms.rb_pots(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8853734526900885
# 0.1061438357413306
# 120.10330344258915
# 0.8774598138069016
# 3.1157895193227323

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.9675196372632172
# 7.833886054421769
# 0.7556957040269832
# 0.04376810759718026
# 0.0010787663667592158
# 84.4375
# 0.3274295892599464
# 0.33155148423005565
# 0.5823938368363539
# 0.04617294239733948
# 3.625
# 0.3274295892599464
# 0.0
# 21.61757794218481
# 20.1875
# 0.9011859131278774

# %%
coms = algorithms.significance_communities(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.7517636624571283
# 0.07816276771676099
# 191.22196969696972
# 0.7325796145406483
# 3.8171983461984014

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.6944446129526434
# 4.31982233044733
# 0.3479422908926585
# 0.3311396267005522
# 0.0060525483386484474
# 13.5
# 1.9295477092352094
# 0.133648088023088
# 1.4831580347756819
# 0.3340496274870103
# 4.4125
# 1.9295477092352094
# 0.1200401334776335
# 55.05258192893632
# 4.0375
# 0.38937499999999997

# %%
coms = algorithms.spinglass(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8832220092501939
# 0.10624708535082197
# 120.58170729679945
# 0.8758063094526649
# 3.0723672812166027

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.9466497249050835
# 7.476131156274827
# 0.7190471656778549
# 0.06299993334846175
# 0.001246124383688718
# 79.52941176470588
# 0.38308955058074057
# 0.32815469296222893
# 0.5923534118796558
# 0.06522154555634842
# 3.235294117647059
# 0.38308955058074057
# 0.0
# 21.98726229691488
# 19.0
# 0.8539387341772812

# %%
coms = algorithms.surprise_communities(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.2312441536378172
# 0.00010325408547578666
# -1506.0
# 0.22689106027559555
# 3.4388464504491423

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.3086131645587039
# 2.0031055900621118
# 0.0
# 0.691431201013612
# 0.020745817539778486
# 1.0062111801242235
# 6.680124223602484
# 0.0
# 0.009316770186335404
# 0.69381071451412
# 6.683229813664596
# 6.680124223602484
# 0.8307453416149069
# 0.34582441113490364
# 1.0031055900621118
# 0.0

# %%
coms = algorithms.walktrap(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8794871728355098
# 0.10779577486964902
# 110.76993752859605
# 0.8729458564571754
# 2.874569055630773

# %%
ae = evaluation.avg_embeddedness(g, coms)
aid = evaluation.average_internal_degree(g, coms)
at = evaluation.avg_transitivity(g, coms)
c = evaluation.conductance(g, coms)
cr = evaluation.cut_ratio(g, coms)
ei = evaluation.edges_inside(g, coms)
ex = evaluation.expansion(g, coms)
fomd = evaluation.fraction_over_median_degree(g, coms)
ied = evaluation.internal_edge_density(g, coms)
nc = evaluation.normalized_cut(g, coms)
modf = evaluation.max_odf(g, coms)
aodf = evaluation.avg_odf(g, coms)
fodf = evaluation.flake_odf(g, coms)
sd = evaluation.scaled_density(g, coms)
sz = evaluation.size(g, coms)
tpr = evaluation.triangle_participation_ratio(g, coms)

print(ae.score)
print(aid.score)
print(at.score)
print(c.score)
print(cr.score)
print(ei.score)
print(ex.score)
print(fomd.score)
print(ied.score)
print(nc.score)
print(modf.score)
print(aodf.score)
print(fodf.score)
print(sd.score)
print(sz.score)
print(tpr.score)
# Out:
# 0.9731383314078896
# 7.627034637953337
# 0.7044107437826026
# 0.03659765196036367
# 0.0007983759867706744
# 91.13333333333334
# 0.24237213604693283
# 0.3285950145055836
# 0.6691193834638421
# 0.03837329542304445
# 2.6666666666666665
# 0.24237213604693283
# 0.0
# 24.83669899947908
# 21.533333333333335
# 0.8410848801499209
