# %%
import pandas as pd

df = pd.read_excel('./../data/adjmatrix.xlsx')

# %%
df = df.dropna(axis=0, thresh=3)
df = df.dropna(axis=1, thresh=3)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df[df < 0.5] = 0

# %%
import networkx as nx

graph = nx.from_numpy_matrix(df.values)
graph = nx.relabel_nodes(graph, dict(enumerate(df.columns)))
nodes_of_largest_component  = max(nx.connected_components(graph), key = len)
g = graph.subgraph(nodes_of_largest_component)
nx.draw_networkx(g)

# %%
from cdlib import algorithms, viz

# Value of k = ?
#coms = algorithms.async_fluid(g, k=?)
#pos = nx.spring_layout(g)
#viz.plot_network_clusters(g, coms, pos)
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'karateclub', 'infomap', 'graph_tool'}
# Note: to be able to use all overlapping methods, you need to install some additional packages:  {'ASLPAw', 'karateclub'}
# Note: to be able to use all bipartite methods, you need to install some additional packages:  {'wurlitzer', 'infomap'}

# %%
coms = algorithms.belief(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
from cdlib import evaluation

m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8066889651111794
# 0.10542115806067426
# 56.005676061527126
# 0.8146410676701674
# 2.243817391155604

# %%
coms = algorithms.cpm(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.2305496074232691
# 0.0
# -1510.0
# 0.3228576392512447
# 3.4316485879321283

# %%
# Frozen graph can't be modified
# coms = algorithms.chinesewhispers(g)
# pos = nx.spring_layout(g)
# viz.plot_network_clusters(g, coms, pos)

# %%
# m1 = evaluation.erdos_renyi_modularity(g, coms)
# m2 = evaluation.link_modularity(g, coms)
# m3 = evaluation.modularity_density(g, coms)
# m4 = evaluation.newman_girvan_modularity(g, coms)
# m5 = evaluation.z_modularity(g, coms)

# print(m1.score)
# print(m2.score)
# print(m3.score)
# print(m4.score)
# print(m5.score)

# %%
coms = algorithms.der(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.4679620622007985
# 0.10645345914297448
# 16.173811349693253
# 0.4694615520694616
# 0.9260713207759199

# %%
coms = algorithms.eigenvector(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8397818371072672
# 0.09664501646886144
# 122.02863472784526
# 0.8482318286536176
# 3.2610074118889814

# %%
#coms = algorithms.em(g, k=?)
#pos = nx.spring_layout(g)
#viz.plot_network_clusters(g, coms, pos)

# %%
# m1 = evaluation.erdos_renyi_modularity(g, coms)
# m2 = evaluation.link_modularity(g, coms)
# m3 = evaluation.modularity_density(g, coms)
# m4 = evaluation.newman_girvan_modularity(g, coms)
# m5 = evaluation.z_modularity(g, coms)

# print(m1.score)
# print(m2.score)
# print(m3.score)
# print(m4.score)
# print(m5.score)

# %%
coms = algorithms.ga(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.6846022019566407
# 0.06979923656411452
# 67.93367974148907
# 0.6687539898339155
# 3.2498688066788213

# %%
# Value of level = ?
# coms = algorithms.girvan_newman(g, level=?)
# pos = nx.spring_layout(g)
# viz.plot_network_clusters(g, coms, pos)

# %%
# m1 = evaluation.erdos_renyi_modularity(g, coms)
# m2 = evaluation.link_modularity(g, coms)
# m3 = evaluation.modularity_density(g, coms)
# m4 = evaluation.newman_girvan_modularity(g, coms)
# m5 = evaluation.z_modularity(g, coms)

# print(m1.score)
# print(m2.score)
# print(m3.score)
# print(m4.score)
# print(m5.score)

# %%
coms = algorithms.greedy_modularity(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8740507379996182
# 0.1071762518901595
# 106.1353735577178
# 0.867665647205193
# 2.844998987043929

# %%
coms = algorithms.kcut(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.0029683814293752983
# 0.10552360553924804
# -33.708860759493675
# 0.009259471540925556
# 0.04279861336050962

# %%
coms = algorithms.label_propagation(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.2305496074232691
# 0.0
# -1510.0
# 0.22618620023119979
# 3.4316485879321283

# %%
coms = algorithms.leiden(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8853734526900885
# 0.10614383574133046
# 120.10330344258915
# 0.8774598138069016
# 3.1157895193227314

# %%
coms = algorithms.louvain(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8817064210716552
# 0.10727953137032074
# 113.40435779906366
# 0.8744615475537256
# 2.9452054230012448

# %%
# Frozen graph can't be modified
# coms = algorithms.markov_clustering(g)
# pos = nx.spring_layout(g)
# viz.plot_network_clusters(g, coms, pos)

# %%
# m1 = evaluation.erdos_renyi_modularity(g, coms)
# m2 = evaluation.link_modularity(g, coms)
# m3 = evaluation.modularity_density(g, coms)
# m4 = evaluation.newman_girvan_modularity(g, coms)
# m5 = evaluation.z_modularity(g, coms)

# print(m1.score)
# print(m2.score)
# print(m3.score)
# print(m4.score)
# print(m5.score)

# %%
coms = algorithms.rber_pots(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8871921585043346
# 0.1049048597281529
# 136.7763294970612
# 0.8737806328812753
# 3.1853557233649563

# %%
coms = algorithms.rb_pots(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8853734526900885
# 0.10614383574133046
# 120.10330344258915
# 0.8774598138069016
# 3.1157895193227314

# %%
coms = algorithms.significance_communities(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.74730794027243
# 0.07754326587818539
# 190.9146131646132
# 0.729119763032523
# 3.8390088268330165

# %%
coms = algorithms.spinglass(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8817755023549609
# 0.10779579845704876
# 102.4745644396566
# 0.8755235502733085
# 2.9157174545593976

# %%
coms = algorithms.surprise_communities(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.2312441536378172
# 0.00010325407883342042
# -1493.0
# 0.2268579443356709
# 3.425454005697435

# %%
coms = algorithms.walktrap(g)
pos = nx.spring_layout(g)
viz.plot_network_clusters(g, coms, pos)

# %%
m1 = evaluation.erdos_renyi_modularity(g, coms)
m2 = evaluation.link_modularity(g, coms)
m3 = evaluation.modularity_density(g, coms)
m4 = evaluation.newman_girvan_modularity(g, coms)
m5 = evaluation.z_modularity(g, coms)

print(m1.score)
print(m2.score)
print(m3.score)
print(m4.score)
print(m5.score)
# Out:
# 0.8794871728355098
# 0.10779577486964903
# 110.76993752859605
# 0.8729458564571754
# 2.874569055630773
